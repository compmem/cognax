# %%
import numpy as np
import matplotlib.pyplot as plt

import jax
import jax.numpy as jnp
import jax.random as random

import numpyro
import numpyro.distributions as dist
from numpyro.infer import SVI, Trace_ELBO, NUTS, MCMC, Predictive
from numpyro.infer.autoguide import AutoDelta

from cognax.decisions import WFPT

numpyro.enable_x64(True)
numpyro.set_platform("cpu")

# %%
# --- plotting ---
def dhist(dat, nvals, ax, alpha=0.3):
    p, b = np.histogram(dat, bins="auto", density=True)
    w = b[1] - b[0]
    p *= float(len(dat)) / nvals
    return ax.bar(b[1:] - w, p, width=w, alpha=alpha)


def choice_rt_hist(choice_rts, valid_choices, ax):
    choices, rts = choice_rts[..., 0], choice_rts[..., 1]

    for choice_i in valid_choices:
        choice_i_rts = rts[choices == choice_i]
        dhist(choice_i_rts, choices.size, ax)


def plot_wfpt(choice_rts, fitted_wfpt, max_RT=3.0, ax=None):
    if ax is None:
        fig, ax = plt.subplots(figsize=(5, 3))

    xvals = np.linspace(0.0, max_RT, 1000)
    choice_rt_hist(choice_rts, fitted_wfpt.valid_choice_values, ax)

    for choice_i in fitted_wfpt.valid_choice_values:
        vals = np.vstack([np.zeros(len(xvals)) + choice_i, xvals]).T
        likes = np.exp(fitted_wfpt.log_prob(vals))
        ax.plot(xvals, likes, lw=2.0)

    ax.set_xlim(0, max_RT)

# %%
# synthesize choice_RT data
data_key, map_key, mcmc_key = random.split(random.PRNGKey(0), 3)
wfpt = WFPT(-1, 2, 0.8, 0.2, dt=0.001, rel_max_time=5)
choice_RTs = wfpt.sample(data_key, (1000,))

plot_wfpt(choice_RTs, wfpt, max_RT=6.0)

# %%
max_nondecision_time = jnp.min(choice_RTs[..., 1])


def model(data):
    v = numpyro.sample("v", dist.Normal(0, 2))
    a = numpyro.sample("a", dist.LogNormal(1, 1))
    w = numpyro.sample("w", dist.Beta(1, 1))
    t0 = numpyro.sample("t0", dist.Uniform(0, max_nondecision_time))

    with numpyro.plate("n_trial", 1000, dim=-1):
        numpyro.sample("obs", WFPT(v, a, w, t0), obs=data)

# %%
guide = AutoDelta(model)
optimizer = numpyro.optim.Adam(0.03)
svi = SVI(model, guide, optimizer, Trace_ELBO())

svi_result = svi.run(map_key, 1000, choice_RTs)

params = guide.sample_posterior(random.PRNGKey(0), svi_result.params, choice_RTs)
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_33620\2741134823.py:5: UserWarning: Site obs: Out-of-support values provided to log prob method. The value argument should be within the support.
#   svi_result = svi.run(map_key, 1000, choice_RTs)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 5
#       2 optimizer = numpyro.optim.Adam(0.03)
#       3 svi = SVI(model, guide, optimizer, Trace_ELBO())
# ----> 5 svi_result = svi.run(map_key, 1000, choice_RTs)
#       7 params = guide.sample_posterior(random.PRNGKey(0), svi_result.params, choice_RTs)
#
# File c:\Users\chris\Desktop\GitHub\cognax\.venv\Lib\site-packages\numpyro\infer\svi.py:401, in SVI.run(self, rng_key, num_steps, progress_bar, stable_update, forward_mode_differentiation, init_state, init_params, *args, **kwargs)
#     398     return svi_state, loss
#     400 if init_state is None:
# --> 401     svi_state = self.init(rng_key, *args, init_params=init_params, **kwargs)
#     402 else:
#     403     svi_state = init_state
#
# File c:\Users\chris\Desktop\GitHub\cognax\.venv\Lib\site-packages\numpyro\infer\svi.py:184, in SVI.init(self, rng_key, init_params, *args, **kwargs)
#     182 if init_params is not None:
#     183     guide_init = substitute(guide_init, init_params)
# --> 184 guide_trace = trace(guide_init).get_trace(*args, **kwargs, **self.static_kwargs)
#     185 init_guide_params = {
#     186     name: site["value"]
#     187     for name, site in guide_trace.items()
#     188     if site["type"] == "param"
#     189 }
#     190 if init_params is not None:
#
# File c:\Users\chris\Desktop\GitHub\cognax\.venv\Lib\site-packages\numpyro\handlers.py:191, in trace.get_trace(self, *args, **kwargs)
#     183 def get_trace(self, *args, **kwargs) -> OrderedDict[str, Message]:
#     184     """
#     185     Run the wrapped callable and return the recorded trace.
#     186
#    (...)
#     189     :return: `OrderedDict` containing the execution trace.
#     190     """
# --> 191     self(*args, **kwargs)
#     192     return self.trace
#
# File c:\Users\chris\Desktop\GitHub\cognax\.venv\Lib\site-packages\numpyro\primitives.py:121, in Messenger.__call__(self, *args, **kwargs)
#     119     return self
#     120 with self:
# --> 121     return self.fn(*args, **kwargs)
#
# File c:\Users\chris\Desktop\GitHub\cognax\.venv\Lib\site-packages\numpyro\primitives.py:121, in Messenger.__call__(self, *args, **kwargs)
#     119     return self
#     120 with self:
# --> 121     return self.fn(*args, **kwargs)
#
# File c:\Users\chris\Desktop\GitHub\cognax\.venv\Lib\site-packages\numpyro\infer\autoguide.py:561, in AutoDelta.__call__(self, *args, **kwargs)
#     558 def __call__(self, *args, **kwargs):
#     559     if self.prototype_trace is None:
#     560         # run model to inspect the model structure
# --> 561         self._setup_prototype(*args, **kwargs)
#     563     plates = self._create_plates(*args, **kwargs)
#     564     result = {}
#
# File c:\Users\chris\Desktop\GitHub\cognax\.venv\Lib\site-packages\numpyro\infer\autoguide.py:535, in AutoDelta._setup_prototype(self, *args, **kwargs)
#     534 def _setup_prototype(self, *args, **kwargs):
# --> 535     super()._setup_prototype(*args, **kwargs)
#     536     with numpyro.handlers.block():
#     537         self._init_locs = {
#     538             k: v
#     539             for k, v in self._postprocess_fn(self._init_locs).items()
#     540             if k in self._init_locs
#     541         }
#
# File c:\Users\chris\Desktop\GitHub\cognax\.venv\Lib\site-packages\numpyro\infer\autoguide.py:158, in AutoGuide._setup_prototype(self, *args, **kwargs)
#     151 rng_key = numpyro.prng_key()
#     152 with handlers.block():
#     153     (
#     154         init_params,
#     155         self._potential_fn_gen,
#     156         postprocess_fn_gen,
#     157         self.prototype_trace,
# --> 158     ) = initialize_model(
#     159         rng_key,
#     160         self.model,
#     161         init_strategy=self.init_loc_fn,
#     162         dynamic_args=True,
#     163         model_args=args,
#     164         model_kwargs=kwargs,
#     165     )
#     166 self._potential_fn = self._potential_fn_gen(*args, **kwargs)
#     167 postprocess_fn = postprocess_fn_gen(*args, **kwargs)
#
# File c:\Users\chris\Desktop\GitHub\cognax\.venv\Lib\site-packages\numpyro\infer\util.py:795, in initialize_model(rng_key, model, init_strategy, dynamic_args, model_args, model_kwargs, forward_mode_differentiation, validate_grad)
#     782                             w.message.args = (
#     783                                 "Site {}: {}".format(
#     784                                     site["name"], w.message.args[0]
#     785                                 ),
#     786                             ) + w.message.args[1:]
#     787                             warnings.showwarning(
#     788                                 w.message,
#     789                                 w.category,
#    (...)
#     793                                 line=w.line,
#     794                             )
# --> 795         raise RuntimeError(
#     796             "Cannot find valid initial parameters. Please check your model again."
#     797         )
#     798 return ModelInfo(
#     799     ParamInfo(init_params, pe, grad), potential_fn, postprocess_fn, model_trace
#     800 )
#
# RuntimeError: Cannot find valid initial parameters. Please check your model again.

# %%
fig, axs = plt.subplots(ncols=2, figsize=(10, 3))

axs[0].plot(svi_result.losses)
axs[0].set_title("-log_posterior")
plot_wfpt(choice_RTs, WFPT(params["v"], params["a"], params["w"], params["t0"]), ax=axs[1])
axs[1].set_title("best fit params vs. real data")
# Out:
# Text(0.5, 1.0, 'best fit params vs. real data')

# %%
predictive = Predictive(
    model, guide=guide, params=params, num_samples=1
)  # gives us 1 sample for each original sample in the data
map_predictive = predictive(random.PRNGKey(0), None)["obs"]

fig, axs = plt.subplots(ncols=2, figsize=(10, 5))

choice_rt_hist(map_predictive, n_choice=3, ax=axs[0])
axs[0].set_title("predicted")

choice_rt_hist(choice_RTs, n_choice=3, ax=axs[1])
axs[1].set_title("actual")
# Out:
# c:\Users\chris\Desktop\GitHub\cognax\.venv\Lib\site-packages\numpy\lib\_histograms_impl.py:901: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Text(0.5, 1.0, 'actual')

# %%
# --- fit full posteriors with MCMC ---
kernel = NUTS(model)
sampler = MCMC(kernel, num_warmup=500, num_samples=500, num_chains=1)

sampler.run(mcmc_key, choice_RTs)

sampler.print_summary()

mean_params = {key: np.mean(val, axis=0) for key, val in sampler.get_samples().items()}

plot_wfpt(choice_RTs, WFPT(mean_params["v"], mean_params["a"], mean_params["w"], mean_params["t0"]))
plt.title("best fit params vs. real data")
# Out:
# sample: 100%|██████████| 1000/1000 [00:06<00:00, 150.02it/s, 7 steps of size 5.43e-01. acc. prob=0.91]
#                 mean       std    median      5.0%     95.0%     n_eff     r_hat
#          a      2.20      0.03      2.20      2.14      2.25    336.68      1.00
#         t0      0.20      0.01      0.20      0.19      0.21    319.97      1.00
#          v      0.03      0.03      0.03     -0.04      0.08    276.50      1.00
#          w      0.30      0.01      0.30      0.28      0.31    260.25      1.00
#
# Number of divergences: 0
# Text(0.5, 1.0, 'best fit params vs. real data')

# %%
predictive = Predictive(model, posterior_samples=sampler.get_samples())

predictive_samps = predictive(random.PRNGKey(0), None)["obs"]

fig, axs = plt.subplots(ncols=2, figsize=(10, 5))

choice_rt_hist(map_predictive, n_choice=3, ax=axs[0])
axs[0].set_title("predicted")

choice_rt_hist(choice_RTs, n_choice=3, ax=axs[1])
axs[1].set_title("actual")
# Out:
# /home/ami/venvs/jax/lib/python3.11/site-packages/numpy/lib/histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# Text(0.5, 1.0, 'actual')
